# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
merge_df = pd.merge(school_data, student_data, on="school_name")
merge_df
# Out:
#        School ID         school_name      type  size   budget  Student ID  \
# 0              0   Huang High School  District  2917  1910635           0
# 1              0   Huang High School  District  2917  1910635           1
# 2              0   Huang High School  District  2917  1910635           2
# 3              0   Huang High School  District  2917  1910635           3
# 4              0   Huang High School  District  2917  1910635           4
# ...          ...                 ...       ...   ...      ...         ...
# 39165         14  Thomas High School   Charter  1635  1043130       39165
# 39166         14  Thomas High School   Charter  1635  1043130       39166
# 39167         14  Thomas High School   Charter  1635  1043130       39167
# 39168         14  Thomas High School   Charter  1635  1043130       39168
# 39169         14  Thomas High School   Charter  1635  1043130       39169
#
#             student_name gender grade  reading_score  math_score
# ...

# %%
#calculate the total number of schools
total_schools = len(merge_df["school_name"].value_counts())
total_schools
# Out:
# 15

# %%
#calculate the total number of students
total_students = len(merge_df["Student ID"].value_counts())
total_students
# Out:
# 39170

# %%
#calculate the total budget

budget = merge_df["budget"].unique()

total_budget = budget.sum()

total_budget
# Out:
# 24649428

# %%
#Calculate the average math score

avg_math = merge_df["math_score"].mean()
avg_math
# Out:
# 78.98537145774827

# %%
#Calculate the average reading score

avg_reading = merge_df ["reading_score"].mean()
avg_reading
# Out:
# 81.87784018381414

# %%
#Calculate the percentage of students with a passing math score (70 or greater)

math_passing = merge_df.loc[merge_df["math_score"] >= 70]["math_score"].count()

percent_pass_math = (math_passing / total_students) * 100
percent_pass_math
# Out:
# 74.9808526933878

# %%
#Calculate the percentage of students with a passing reading score (70 or greater)


reading_passing = merge_df.loc[merge_df["reading_score"] >= 70]["reading_score"].count()

percent_pass_reading = reading_passing / total_students * 100
percent_pass_reading
# Out:
# 85.80546336482001

# %%
#Calculate the percentage of students who passed math and reading (% Overall Passing)

total_pass = merge_df.loc[(merge_df["math_score"] >= 70) & (merge_df["reading_score"] >=70)]["student_name"].count()

percent_passing = total_pass / total_students * 100
percent_passing
# Out:
# 65.17232575950983

# %%
#Create a dataframe to hold the above results

district_summary_df = pd.DataFrame({
    
    "Total Schools": [total_schools],
    "Total Students": [total_students],
    "Total Budget": [total_budget],
    "Average Math Score": [avg_math],
    "Average Reading Score": [avg_reading],
    "% Passing Math":[percent_pass_math],
    "% Passing Reading": [percent_pass_reading],
    "% Overall Passing": [percent_passing]

})

district_summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
summary_styling_df = district_summary_df.style.format({"Total Budget": "${:,.2f}", 
                                                       "Total Students": "{:,}"})


summary_styling_df
# Out:
# <style  type="text/css" >
# </style><table id="T_fb6192fa_c226_11ea_b679_3cf011be6bf7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Schools</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total Budget</th>        <th class="col_heading level0 col3" >Average Math Score</th>        <th class="col_heading level0 col4" >Average Reading Score</th>        <th class="col_heading level0 col5" >% Passing Math</th>        <th class="col_heading level0 col6" >% Passing Reading</th>        <th class="col_heading level0 col7" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb6192fa_c226_11ea_b679_3cf011be6bf7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fb6192fa_c226_11ea_b679_3cf011be6bf7row0_col0" class="data row0 col0" >15</td>
# ...

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#summarize by school_name 

school_df = merge_df.groupby("school_name")

school_df.count().head(15)
# Out:
#                        School ID  type  size  budget  Student ID  \
# school_name
# Bailey High School          4976  4976  4976    4976        4976
# Cabrera High School         1858  1858  1858    1858        1858
# Figueroa High School        2949  2949  2949    2949        2949
# Ford High School            2739  2739  2739    2739        2739
# Griffin High School         1468  1468  1468    1468        1468
# Hernandez High School       4635  4635  4635    4635        4635
# Holden High School           427   427   427     427         427
# Huang High School           2917  2917  2917    2917        2917
# Johnson High School         4761  4761  4761    4761        4761
# Pena High School             962   962   962     962         962
# Rodriguez High School       3999  3999  3999    3999        3999
# Shelton High School         1761  1761  1761    1761        1761
# Thomas High School          1635  1635  1635    1635        1635
# ...

# %%
#summarize by school_type

type_df = school_data.set_index("school_name")["type"]

type_df
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
#summarize total_students

student_count_df = merge_df["school_name"].value_counts()

student_count_df
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
school_budget_df = school_df.mean()["budget"]
school_budget_df
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# Name: budget, dtype: float64

# %%
#summarize per student budget

per_student_df = school_df.mean()["budget"] / student_count_df

per_student_df
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
#summarize average math score

average_math = school_df["math_score"].mean()
average_math
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
#summarize average reading score

average_reading = school_df ["reading_score"].mean()
average_reading
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
#summarize % passing math

passing_math = merge_df[merge_df["math_score"] >= 70].groupby("school_name")["School ID"].count()/student_count_df*100
passing_math
# Out:
# school_name
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# Name: School ID, dtype: float64

# %%
#summarize % passing reading

passing_reading = merge_df[merge_df["reading_score"] >= 70].groupby("school_name")["School ID"].count()/student_count_df*100
passing_reading
# Out:
# school_name
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# Name: School ID, dtype: float64

# %%
#summarize % overall passing (students that passed both math and reading)

passing_overall = merge_df[(merge_df["reading_score"] >= 70) & (merge_df["math_score"] >= 70)].groupby("school_name")["School ID"].count()/student_count_df*100
passing_overall
# Out:
# school_name
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# Name: School ID, dtype: float64

# %%
type(passing_overall)
# Out:
# pandas.core.series.Series

# %%
# create a dataframe to hold the above results

school_summary_df = pd.DataFrame({
    "School Type": type_df,
    "Total Students": student_count_df,
    "Total School Budget": school_budget_df,
    "Per Student Budget": per_student_df,
    "Average Math Score": average_math,
    "Average Reading Score": average_reading,
    "% Passing Math": passing_math,
    "% Passing Reading": passing_reading,
    "% Overall Passing": passing_overall
})


school_summary_df
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976            3124928.0
# Cabrera High School       Charter            1858            1081356.0
# Figueroa High School     District            2949            1884411.0
# Ford High School         District            2739            1763916.0
# Griffin High School       Charter            1468             917500.0
# Hernandez High School    District            4635            3022020.0
# Holden High School        Charter             427             248087.0
# Huang High School        District            2917            1910635.0
# Johnson High School      District            4761            3094650.0
# Pena High School          Charter             962             585858.0
# Rodriguez High School    District            3999            2547363.0
# Shelton High School       Charter            1761            1056600.0
# ...

# %%
school_summary_styling_df = school_summary_df.style.format({"Total School Budget": "${:,.2f}", 
                                                       "Per Student Budget": "${:,.2f}"})
school_summary_styling_df
# Out:
# <style  type="text/css" >
# </style><table id="T_d85af368_c2e2_11ea_be47_3cf011be6bf7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >School Type</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total School Budget</th>        <th class="col_heading level0 col3" >Per Student Budget</th>        <th class="col_heading level0 col4" >Average Math Score</th>        <th class="col_heading level0 col5" >Average Reading Score</th>        <th class="col_heading level0 col6" >% Passing Math</th>        <th class="col_heading level0 col7" >% Passing Reading</th>        <th class="col_heading level0 col8" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d85af368_c2e2_11ea_be47_3cf011be6bf7level0_row0" class="row_heading level0 row0" >Bailey High School</th>
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
performing_schools_df = school_summary_df.nlargest(5,["% Overall Passing"])


performing_schools_df
# Out:
#                     School Type  Total Students  Total School Budget  \
# Cabrera High School     Charter            1858            1081356.0
# Thomas High School      Charter            1635            1043130.0
# Griffin High School     Charter            1468             917500.0
# Wilson High School      Charter            2283            1319574.0
# Pena High School        Charter             962             585858.0
#
#                      Per Student Budget  Average Math Score  \
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %%
performing_styling = performing_schools_df.style.format({"Total School Budget": "${:,.2f}", 
                                                       "Per Student Budget": "${:,.2f}"})
performing_styling
# Out:
# <style  type="text/css" >
# </style><table id="T_ed040808_c2e3_11ea_886c_3cf011be6bf7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >School Type</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total School Budget</th>        <th class="col_heading level0 col3" >Per Student Budget</th>        <th class="col_heading level0 col4" >Average Math Score</th>        <th class="col_heading level0 col5" >Average Reading Score</th>        <th class="col_heading level0 col6" >% Passing Math</th>        <th class="col_heading level0 col7" >% Passing Reading</th>        <th class="col_heading level0 col8" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ed040808_c2e3_11ea_886c_3cf011be6bf7level0_row0" class="row_heading level0 row0" >Cabrera High School</th>
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_schools = school_summary_df.nsmallest(5,["% Overall Passing"])
bottom_schools
# Out:
#                       School Type  Total Students  Total School Budget  \
# Rodriguez High School    District            3999            2547363.0
# Figueroa High School     District            2949            1884411.0
# Huang High School        District            2917            1910635.0
# Hernandez High School    District            4635            3022020.0
# Johnson High School      District            4761            3094650.0
#
#                        Per Student Budget  Average Math Score  \
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# ...

# %%
bottom_styling = bottom_schools.style.format({"Total School Budget": "${:,.2f}", 
                                                       "Per Student Budget": "${:,.2f}"})
bottom_styling
# Out:
# <style  type="text/css" >
# </style><table id="T_3dd239fa_c2e4_11ea_8a09_3cf011be6bf7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >School Type</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total School Budget</th>        <th class="col_heading level0 col3" >Per Student Budget</th>        <th class="col_heading level0 col4" >Average Math Score</th>        <th class="col_heading level0 col5" >Average Reading Score</th>        <th class="col_heading level0 col6" >% Passing Math</th>        <th class="col_heading level0 col7" >% Passing Reading</th>        <th class="col_heading level0 col8" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3dd239fa_c2e4_11ea_8a09_3cf011be6bf7level0_row0" class="row_heading level0 row0" >Rodriguez High School</th>
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
merge_df
# Out:
#        School ID         school_name      type  size   budget  Student ID  \
# 0              0   Huang High School  District  2917  1910635           0
# 1              0   Huang High School  District  2917  1910635           1
# 2              0   Huang High School  District  2917  1910635           2
# 3              0   Huang High School  District  2917  1910635           3
# 4              0   Huang High School  District  2917  1910635           4
# ...          ...                 ...       ...   ...      ...         ...
# 39165         14  Thomas High School   Charter  1635  1043130       39165
# 39166         14  Thomas High School   Charter  1635  1043130       39166
# 39167         14  Thomas High School   Charter  1635  1043130       39167
# 39168         14  Thomas High School   Charter  1635  1043130       39168
# 39169         14  Thomas High School   Charter  1635  1043130       39169
#
#             student_name gender grade  reading_score  math_score
# ...

# %%
ninth_grade = merge_df.loc[merge_df["grade"] == "9th"][:]

ninth_grade
# Out:
#        School ID         school_name      type  size   budget  Student ID  \
# 0              0   Huang High School  District  2917  1910635           0
# 4              0   Huang High School  District  2917  1910635           4
# 5              0   Huang High School  District  2917  1910635           5
# 12             0   Huang High School  District  2917  1910635          12
# 13             0   Huang High School  District  2917  1910635          13
# ...          ...                 ...       ...   ...      ...         ...
# 39152         14  Thomas High School   Charter  1635  1043130       39152
# 39153         14  Thomas High School   Charter  1635  1043130       39153
# 39157         14  Thomas High School   Charter  1635  1043130       39157
# 39164         14  Thomas High School   Charter  1635  1043130       39164
# 39167         14  Thomas High School   Charter  1635  1043130       39167
#
#            student_name gender grade  reading_score  math_score
# ...

# %%
grouped_school_ninth = ninth_grade.groupby(['school_name'])

print(grouped_school_ninth)
grouped_school_ninth.count().head(15)
# Out:
# ...
#                        School ID  type  size  budget  Student ID  \
# school_name
# Bailey High School          1458  1458  1458    1458        1458
# Cabrera High School          528   528   528     528         528
# Figueroa High School         856   856   856     856         856
# Ford High School             833   833   833     833         833
# Griffin High School          409   409   409     409         409
# Hernandez High School       1382  1382  1382    1382        1382
# Holden High School           127   127   127     127         127
# Huang High School            844   844   844     844         844
# Johnson High School         1400  1400  1400    1400        1400
# Pena High School             275   275   275     275         275
# Rodriguez High School       1164  1164  1164    1164        1164
# Shelton High School          530   530   530     530         530
# Thomas High School           461   461   461     461         461
# ...

# %%
ninth_grade_avg = grouped_school_ninth["math_score"].mean()
ninth_grade_avg
# Out:
# school_name
# Bailey High School       77.083676
# Cabrera High School      83.094697
# Figueroa High School     76.403037
# Ford High School         77.361345
# Griffin High School      82.044010
# Hernandez High School    77.438495
# Holden High School       83.787402
# Huang High School        77.027251
# Johnson High School      77.187857
# Pena High School         83.625455
# Rodriguez High School    76.859966
# Shelton High School      83.420755
# Thomas High School       83.590022
# Wilson High School       83.085578
# Wright High School       83.264706
# Name: math_score, dtype: float64

# %%
tenth_grade = merge_df.loc[merge_df["grade"] == "10th"][:]
grouped_school_tenth = tenth_grade.groupby(['school_name'])
tenth_grade_avg = grouped_school_tenth["math_score"].mean()
tenth_grade_avg
# Out:
# school_name
# Bailey High School       76.996772
# Cabrera High School      83.154506
# Figueroa High School     76.539974
# Ford High School         77.672316
# Griffin High School      84.229064
# Hernandez High School    77.337408
# Holden High School       83.429825
# Huang High School        75.908735
# Johnson High School      76.691117
# Pena High School         83.372000
# Rodriguez High School    76.612500
# Shelton High School      82.917411
# Thomas High School       83.087886
# Wilson High School       83.724422
# Wright High School       84.010288
# Name: math_score, dtype: float64

# %%
eleventh_grade = merge_df.loc[merge_df["grade"] == "11th"][:]
grouped_school_eleventh = eleventh_grade.groupby(['school_name'])
eleventh_grade_avg = grouped_school_eleventh["math_score"].mean()
eleventh_grade_avg
# Out:
# school_name
# Bailey High School       77.515588
# Cabrera High School      82.765560
# Figueroa High School     76.884344
# Ford High School         76.918058
# Griffin High School      83.842105
# Hernandez High School    77.136029
# Holden High School       85.000000
# Huang High School        76.446602
# Johnson High School      77.491653
# Pena High School         84.328125
# Rodriguez High School    76.395626
# Shelton High School      83.383495
# Thomas High School       83.498795
# Wilson High School       83.195326
# Wright High School       83.836782
# Name: math_score, dtype: float64

# %%
twelve_grade = merge_df.loc[merge_df["grade"] == "12th"][:]
grouped_school_twelve = twelve_grade.groupby(['school_name'])
twelve_grade_avg = grouped_school_twelve["math_score"].mean()
twelve_grade_avg
# Out:
# school_name
# Bailey High School       76.492218
# Cabrera High School      83.277487
# Figueroa High School     77.151369
# Ford High School         76.179963
# Griffin High School      83.356164
# Hernandez High School    77.186567
# Holden High School       82.855422
# Huang High School        77.225641
# Johnson High School      76.863248
# Pena High School         84.121547
# Rodriguez High School    77.690748
# Shelton High School      83.778976
# Thomas High School       83.497041
# Wilson High School       83.035794
# Wright High School       83.644986
# Name: math_score, dtype: float64

# %%
math_grade_summary = pd.DataFrame({
    "9th": ninth_grade_avg,
    "10th": tenth_grade_avg,
    "11th": eleventh_grade_avg,
    "12th": twelve_grade_avg
})
math_grade_summary
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
nine_grade = merge_df.loc[merge_df["grade"] == "9th"][:]
grouped_school_nine = nine_grade.groupby(['school_name'])
nine_grade_avg = grouped_school_nine["reading_score"].mean()
nine_grade_avg
# Out:
# school_name
# Bailey High School       81.303155
# Cabrera High School      83.676136
# Figueroa High School     81.198598
# Ford High School         80.632653
# Griffin High School      83.369193
# Hernandez High School    80.866860
# Holden High School       83.677165
# Huang High School        81.290284
# Johnson High School      81.260714
# Pena High School         83.807273
# Rodriguez High School    80.993127
# Shelton High School      84.122642
# Thomas High School       83.728850
# Wilson High School       83.939778
# Wright High School       83.833333
# Name: reading_score, dtype: float64

# %%
ten_grade = merge_df.loc[merge_df["grade"] == "10th"][:]
grouped_school_ten = ten_grade.groupby(['school_name'])
ten_grade_avg = grouped_school_ten["reading_score"].mean()
ten_grade_avg
# Out:
# school_name
# Bailey High School       80.907183
# Cabrera High School      84.253219
# Figueroa High School     81.408912
# Ford High School         81.262712
# Griffin High School      83.706897
# Hernandez High School    80.660147
# Holden High School       83.324561
# Huang High School        81.512386
# Johnson High School      80.773431
# Pena High School         83.612000
# Rodriguez High School    80.629808
# Shelton High School      83.441964
# Thomas High School       84.254157
# Wilson High School       84.021452
# Wright High School       83.812757
# Name: reading_score, dtype: float64

# %%
eleven_grade = merge_df.loc[merge_df["grade"] == "11th"][:]
grouped_school_eleven = eleven_grade.groupby(['school_name'])
eleven_grade_avg = grouped_school_eleven["reading_score"].mean()
eleven_grade_avg
# Out:
# school_name
# Bailey High School       80.945643
# Cabrera High School      83.788382
# Figueroa High School     80.640339
# Ford High School         80.403642
# Griffin High School      84.288089
# Hernandez High School    81.396140
# Holden High School       83.815534
# Huang High School        81.417476
# Johnson High School      80.616027
# Pena High School         84.335938
# Rodriguez High School    80.864811
# Shelton High School      84.373786
# Thomas High School       83.585542
# Wilson High School       83.764608
# Wright High School       84.156322
# Name: reading_score, dtype: float64

# %%
twelveth_grade = merge_df.loc[merge_df["grade"] == "12th"][:]
grouped_school_twelveth = twelveth_grade.groupby(['school_name'])
twelveth_grade_avg = grouped_school_twelveth["reading_score"].mean()
twelveth_grade_avg
# Out:
# school_name
# Bailey High School       80.912451
# Cabrera High School      84.287958
# Figueroa High School     81.384863
# Ford High School         80.662338
# Griffin High School      84.013699
# Hernandez High School    80.857143
# Holden High School       84.698795
# Huang High School        80.305983
# Johnson High School      81.227564
# Pena High School         84.591160
# Rodriguez High School    80.376426
# Shelton High School      82.781671
# Thomas High School       83.831361
# Wilson High School       84.317673
# Wright High School       84.073171
# Name: reading_score, dtype: float64

# %%
reading_grade_summary = pd.DataFrame({
    "9th": nine_grade_avg,
    "10th": ten_grade_avg,
    "11th": eleven_grade_avg,
    "12th": twelveth_grade_avg
})
reading_grade_summary
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
school_spending = school_summary_df

# %%
# Create the bins in which Data will be held

bins = [0, 584, 629, 644, 675]

# Create the names for the five bins
spending_range = ["<$584", "$585-629", "$630-644", "$645-675"]

# %%
# add column with spending range per student to df
school_spending["Spending Ranges (Per Student)"] = pd.cut(school_spending["Per Student Budget"], bins, labels=spending_range)
school_spending

# %%
type(school_spending)
# Out:
# pandas.core.frame.DataFrame

# %%
# Create a GroupBy object based upon "Spending Ranges (Per Student)"
spending_range = school_spending.groupby("Spending Ranges (Per Student)")


# Get the average of each column within the GroupBy object
spending_range = spending_range[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()

spending_range = spending_range.reset_index()

# %%
avg_style = spending_range.style.format({"Average Math Score": "{:,.2f}", 
                                         "Average Reading Score": "{:,.2f}", 
                                         "% Passing Math": "{:,.2f}", 
                                         "% Passing Reading": "{:,.2f}", 
                                         "% Overall Passing": "{:,.2f}"
                                        })
avg_style
# Out:
# <style  type="text/css" >
# </style><table id="T_e80e44e6_c2fa_11ea_a55e_3cf011be6bf7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Spending Ranges (Per Student)</th>        <th class="col_heading level0 col1" >Average Math Score</th>        <th class="col_heading level0 col2" >Average Reading Score</th>        <th class="col_heading level0 col3" >% Passing Math</th>        <th class="col_heading level0 col4" >% Passing Reading</th>        <th class="col_heading level0 col5" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e80e44e6_c2fa_11ea_a55e_3cf011be6bf7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e80e44e6_c2fa_11ea_a55e_3cf011be6bf7row0_col0" class="data row0 col0" ><$584</td>
#                         <td id="T_e80e44e6_c2fa_11ea_a55e_3cf011be6bf7row0_col1" class="data row0 col1" >83.46</td>
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Create the bins in which Data will be held

bins = [0, 1000, 2000, 5000]

# Create the names for the bins
school_size= ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
school_summary_df["School Size"] = pd.cut(school_summary_df["Total Students"], bins, labels=school_size)
school_summary_df
# Out:
#     level_0                  index School Type  Total Students  \
# 0         0     Bailey High School    District            4976
# 1         1    Cabrera High School     Charter            1858
# 2         2   Figueroa High School    District            2949
# 3         3       Ford High School    District            2739
# 4         4    Griffin High School     Charter            1468
# 5         5  Hernandez High School    District            4635
# 6         6     Holden High School     Charter             427
# 7         7      Huang High School    District            2917
# 8         8    Johnson High School    District            4761
# 9         9       Pena High School     Charter             962
# 10       10  Rodriguez High School    District            3999
# 11       11    Shelton High School     Charter            1761
# 12       12     Thomas High School     Charter            1635
# 13       13     Wilson High School     Charter            2283
# ...

# %%
# Create a GroupBy object"

avg_schoolsize = school_summary_df.groupby("School Size")


# Get the average of each column within the GroupBy object
avg_size = avg_schoolsize[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()

avg_size
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          96.790680          90.621535
# Large (2000-5000)           82.766634          58.286003

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# Create a GroupBy object"

school_type = school_summary_df.groupby("School Type")


# Get the average of each column within the GroupBy object
avg_schooltype = school_type[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()

avg_schooltype
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208
